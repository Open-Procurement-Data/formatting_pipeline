# %%
import pipeline
import new_dataframes 
import sys
import pandas as pd

# %%
sys.path.append('pipeline.py')
sys.path.append('new_dataframes.py')

# %%
# specify the data input path 
input_dir = '../new_data'
# specify the data output path, where the DataFrames are saved as json and csv. If no saved output needed, just leave them out 
output_dir_pipe = '../output_pipeline'
# specify if you want to print debugging information
printing = True

dataframes = pipeline.get_dataframes(input_dir, output_dir_pipe, printing)

# Example without output directory and the printing parameter
# dataframes = pipeline.get_dataframes(input_dir)
# Out:
# Output directory created or already exists: ../output_pipeline
# Input directory exists: ../new_data
# Starting extraction for column: parties
# Time taken for extract_2 with column parties: 1.56 seconds
# Starting extraction for column: awards
# Time taken for extract_2 with column awards: 36.02 seconds
# Starting extraction for column: contracts
# /home/tetiana/Tanja/Code/ProcurDat/formatting_pipeline/pipeline.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   combined_df.reset_index(inplace=True)
# Time taken for extract_2 with column contracts: 43.97 seconds
# Starting extraction for column: tender.items
# /home/tetiana/Tanja/Code/ProcurDat/formatting_pipeline/pipeline.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   combined_df.reset_index(inplace=True)
# Time taken for extract_2 with column tender.items: 57.69 seconds
# Starting extraction for column: tender.lots
# /home/tetiana/Tanja/Code/ProcurDat/formatting_pipeline/pipeline.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   combined_df.reset_index(inplace=True)
# Time taken for extract_2 with column tender.lots: 72.73 seconds
# Bescha shape: (2775, 5493)
# Saved DataFrame to ../output_pipeline/2024_07_29_overView_Ted.csv
# Saved DataFrame to ../output_pipeline/2024_07_29_overView_Ted.json
# Saved DataFrame to ../output_pipeline/2024_07_29_overView_Bescha.csv
# Saved DataFrame to ../output_pipeline/2024_07_29_overView_Bescha.json

# %%
dataframes.keys()
# Out:
# dict_keys(['overView_Ted', 'overView_Bescha'])

# %%
# specify the cpv input path 
cpv_input_dir = "../cpv_exel/cpv_2008_ver_2013.xlsx"
# specify the data output path, where the DataFrames are saved as json and csv. If no saved output needed, just leave them out 
output_dir_new_df = "../output_new_dataframes"
# specify if you want to print debugging information
printing_new_def = True

bescha_new, ted_new = new_dataframes.get_new_dataframes(dataframes, cpv_input_dir, output_dir_new_df, printing_new_def)

# Example without output directory and the printing parameter
# bescha_new, ted_new = new_dataframes.get_new_dataframes(dataframes, cpv_input_dir)
# Out:
# Output directory created or already exists: ../output_new_dataframes
# /home/tetiana/Tanja/Code/ProcurDat/.venv/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Processed ../cpv_exel/cpv_2008_ver_2013.xlsx
# bescha_new has following columns: Index(['tender_title', 'tender_description', 'tender_cpv_number',
#        'tender_cpv_category', 'tender_numberOfTenderers', 'buyer_name',
#        'buyer_locality', 'buyer_nut', 'contracts_value_amount'],
#       dtype='object')
# ted_new has following columns: Index(['tender_title', 'tender_description', 'tender_cpv_number',
#        'tender_cpv_category', 'buyer_name', 'buyer_locality', 'buyer_nut',
#        'contracts_value_amount'],
#       dtype='object')
# Saved DataFrame to ../output_new_dataframes/2024_07_29_bescha.csv
# Saved DataFrame to ../output_new_dataframes/2024_07_29_ted.csv

# %%
bescha_new
# Out:
#                                            tender_title  \
# 0     REZ BBSAT 45ind - Mein Weg mein Ziel - Jobcent...
# 1                          REZ Bayern_BvB_AA Ingolstadt
# 2     RV Druck und Lieferung Amtl. Handausgabe Umsat...
# 3                        REZ BBSAT BvB AA Thüringen Ost
# 4                           REZ Nord-BvBReha- AA Lübeck
# ...                                                 ...
# 2770  Max-Planck-Gymnasium, Groß-Umstadt -Ausbau Dac...
# 2771  RBB Müritz AS Malchin, Modernisierung Haus 1, ...
# 2772  Fachplanungsleistungen zur Auslegung und Berec...
# 2773           Leistungsbild Gebäudeplanung Architektur
# 2774  Fachplanungsleistungen Technische Ausrüstung H...
#
#                                      tender_description tender_cpv_number  \
# 0     Konzeption und Durchführung der Maßnahmekombin...               NaN
# 1     §§ 51 und 53 SGB III - Berufsvorbereitende Bil...               NaN
# 2     Rahmenvertrag für Satz, Druck und Lieferung de...               NaN
# 3     Konzeption und Durchführung von Berufsvorberei...          80000000
# 4     Konzeption und Durchführung von Behindertenspe...               NaN
# ...                                                 ...               ...
# 2770                           Metallbau-Türen 2.+3. BA          45262670
# 2771  Der Landkreis Mecklenburgische Seenplatte beab...          71300000
# 2772  Stufenweise Erbringung  von Fachplanungsleistu...          71322000
# 2773  Stufenweise Erbringung von Objektplanungsleist...          71200000
# 2774  Stufenweise Erbringung  von Fachplanungsleistu...          71300000
#
#      tender_cpv_category  tender_numberOfTenderers  \
# 0               services                       0.0
# 1               services                       0.0
# 2                  goods                       0.0
# 3               services                       0.0
# 4               services                       0.0
# ...                  ...                       ...
# 2770                 NaN                       0.0
# 2771            services                       0.0
# 2772            services                       0.0
# 2773            services                       0.0
# 2774            services                       0.0
#
#                                              buyer_name        buyer_locality  \
# 0     Bundesagentur für Arbeit Regionales Einkaufsze...      Halle a.d. Saale
# 1     Bundesagentur für Arbeit Regionales Einkaufsze...              Nürnberg
# 2     Generalzolldirektion Zentrale Beschaffungsstel...              Freiburg
# 3     Bundesagentur für Arbeit Regionales Einkaufsze...      Halle a.d. Saale
# 4     Bundesagentur für Arbeit Regionales Einkaufsze...              Hannover
# ...                                                 ...                   ...
# 2770   Kreisausschuss des Landkreises Darmstadt-Dieburg             Darmstadt
# 2771              Landkreis Mecklenburgische Seenplatte        Neubrandenburg
# 2772                         Stadt Biberach an der Riss  Biberach an der Riss
# 2773                         Stadt Biberach an der Riss  Biberach an der Riss
# 2774                         Stadt Biberach an der Riss  Biberach an der Riss
#
#      buyer_nut  contracts_value_amount
# 0           DE                    0.01
# 1           DE                    0.01
# 2        DE131                    0.01
# 3           DE                    0.01
# 4           DE                     NaN
# ...        ...                     ...
# 2770     DE716               232662.85
# 2771     DE80J               429910.00
# 2772     DE146                36552.60
# 2773     DE146               244235.14
# 2774     DE146               390361.59
#
# [2775 rows x 9 columns]

# %%
ted_new
# Out:
#                                            tender_title  \
# 0     {'hun': 'Németország – Katonai épületek és lét...
# 1     {'hun': 'Németország – Építési munkák – Univer...
# 2     {'hun': 'Németország – Magasépítési munka – KI...
# 3     {'hun': 'Németország – Építési munkák – LAZBW ...
# 4     {'hun': 'Németország – Üzemegységek, ipartelep...
# ...                                                 ...
# 2977  {'hun': 'Németország – Sportcsarnok építése – ...
# 2978  {'hun': 'Németország – Építési munkák – Grunds...
# 2979  {'hun': 'Németország – Épületbővítési munka – ...
# 2980  {'hun': 'Németország – Sportlétesítmények kivi...
# 2981  {'hun': 'Németország – Építési munkák – Grunds...
#
#                                      tender_description tender_cpv_number  \
# 0     {'deu': ['Zwei baugleiche Unterkunftsgebäude f...        [45216200]
# 1     {'deu': ['Art und Umfang der Leistung:&#92;n- ...        [45000000]
# 2     {'deu': ['Umfang der Leistungen (nicht vollstä...        [45210000]
# 3     {'deu': ['Beim vorliegenden Gebäude handelt es...        [45000000]
# 4     {'deu': ['Der ZVH schreibt die Ausführungsplan...        [45213251]
# ...                                                 ...               ...
# 2977                         {'deu': ['Trennvorhänge']}        [45212225]
# 2978  {'deu': ['Werkraumausstattung mit Klappschiebe...        [45000000]
# 2979  {'deu': ['Montage abgehangener Decken Rasterde...        [45262800]
# 2980  {'deu': ['- Werkplanung und Prüfung des fertig...        [45212200]
# 2981  {'deu': ['600 m² Trockenbauwände mit zementgeb...        [45000000]
#
#      tender_cpv_category                                         buyer_name  \
# 0          [Bauarbeiten]  {'deu': ['Staatliches Hochbauamt Schwäbisch Ha...
# 1          [Bauarbeiten]  {'deu': ['Vermögen und Bau Baden-Württemberg A...
# 2          [Bauarbeiten]  {'deu': ['Vermögen und Bau Baden-Württemberg A...
# 3          [Bauarbeiten]  {'deu': ['Vermögen und Bau Baden-Württemberg A...
# 4          [Bauarbeiten]     {'deu': ['Zweckverband Hafen Straubing-Sand']}
# ...                  ...                                                ...
# 2977       [Bauarbeiten]            {'deu': ['Gemeinde Seeheim-Jugenheim']}
# 2978       [Bauarbeiten]  {'deu': ['Stadt Leipzig, Amt für Gebäudemanage...
# 2979       [Bauarbeiten]             {'deu': ['Stadt Bayreuth Hochbauamt']}
# 2980       [Bauarbeiten]  {'deu': ['Stadt Leipzig, Amt für Gebäudemanage...
# 2981       [Bauarbeiten]  {'deu': ['Stadt Leipzig, Amt für Gebäudemanage...
#
#                       buyer_locality buyer_nut  contracts_value_amount
# 0       {'mul': ['Schwäbisch Hall']}   [DE11A]               119504.80
# 1                   {'mul': ['Ulm']}   [DE144]              2052029.00
# 2             {'mul': ['Karlsruhe']}   [DE122]               165703.66
# 3            {'mul': ['Ravensburg']}   [DE148]               294422.62
# 4             {'mul': ['Straubing']}   [DE223]                     NaN
# ...                              ...       ...                     ...
# 2977  {'mul': ['Seeheim-Jugenheim']}   [DE716]                34460.88
# 2978            {'mul': ['Leipzig']}   [DED51]                     NaN
# 2979           {'mul': ['Bayreuth']}   [DE242]                     NaN
# 2980            {'mul': ['Leipzig']}   [DED51]                     NaN
# 2981            {'mul': ['Leipzig']}   [DED51]                     NaN
#
# [2982 rows x 8 columns]
